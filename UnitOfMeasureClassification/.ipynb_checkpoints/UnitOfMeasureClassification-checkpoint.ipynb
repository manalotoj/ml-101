# %%
import pandas as pd

df = pd.read_csv('TD01.csv', encoding = "utf-8")

col = ['Category', 'Value']
df = df[col]
df.columns = ['Category', 'Value']
df['category_id'] = df['Category'].factorize()[0]
category_id_df = df[['Category', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Category']].values)
df
# Out:
# c:\python\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
#          Category                         Value  category_id
# 0          farads                 Capacitance f            0
# 1          farads             Capacitance farad            0
# 2          farads             Capacitance Farad            0
# 3          farads            Capacitance farads            0
# 4    micro farads           Capacitance micro f            1
# 5    micro farads            Capacitance microf            1
# 6    micro farads      Capacitance micro farads            1
# 7    micro farads       Capacitance microfarads            1
# 8    micro farads       Capacitance micro farad            1
# 9    micro farads        Capacitance microfarad            1
# 10    pico farads       Capacitance pico farads            2
# 11    pico farads        Capacitance picofarads            2
# 12    pico farads        Capacitance pico farad            2
# 13    pico farads         Capacitance picofarad            2
# 14    pico farads             Capacitance picof            2
# 15    pico farads            Capacitance pico f            2
# 16   micro farads          Capacitance µ farads            1
# 17   micro farads           Capacitance µfarads            1
# 18   micro farads                Capacitance µf            1
# 19    nano farads                Capacitance nf            3
# 20    nano farads               Capacitance n f            3
# 21    nano farads           Capacitance n farad            3
# 22    nano farads          Capacitance n farads            3
# 23    nano farads        Capacitance nano farad            3
# 24    nano farads         Capacitance nanofarad            3
# 25    nano farads        Capacitance nanofarads            3
# 26    nano farads       Capacitance nano farads            3
# 27   milli farads            Capacitance miliif            4
# 28   milli farads      Capacitance milli farads            4
# 29   milli farads       Capacitance millifarads            4
# ..            ...                           ...          ...
# 102         volts                  Voltage volt           11
# 103         volts                 Voltage volts           11
# 104         volts                   Voltage vdc           11
# 105         volts   Voltage 6.3 V.DC to 50 V.DC           11
# 106         volts              Voltage W.V. (V)           11
# 107         volts                  Voltage W.V.           11
# 108         volts                  Voltage WV V           11
# 109         volts                Voltage SV Vdc           11
# 110         volts                Voltage WV Vdc           11
# 111         volts   Voltage Working Voltage Vdc           11
# 112         volts           Voltage 6.3 ~ 50Vdc           11
# 113         volts             Voltage 6.3~50vdc           11
# 114         volts     Voltage rated voltage vdc           11
# 115         volts     Voltage 4 V.DC to 50 V.DC           11
# 116         volts  Voltage 6.3 V.DC to 100 V.DC           11
# 117         volts  Voltage 6.3 V.DC to 100 V.DC           11
# 118         volts                  Voltage UR V           11
# 119         volts         Voltage 16 V to 100 V           11
# 120         volts  Voltage Rated voltage (in V)           11
# 121         volts  Voltage V=Rated Voltage(Vdc)           11
# 122   micro volts           Voltage micro volts           12
# 123   micro volts            Voltage microvolts           12
# 124   micro volts                    Voltage µv           12
# 125   micro volts                   Voltage µ v           12
# 126   milli volts           Voltage milli volts           13
# 127   milli volts            Voltage millivolts           13
# 128    kilo volts            Voltage kilo volts           14
# 129    kilo volts             Voltage kilovolts           14
# 130    kilo volts                    Voltage kv           14
# 131    kilo volts                   Voltage k v           14
#
# [132 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(analyzer='char', sublinear_tf=True, min_df=1, norm=None, encoding='latin-1', ngram_range=(1, 3), stop_words=None)

features = tfidf.fit_transform(df.Value).toarray()
labels = df.category_id
features.shape
print(labels)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
# 5       1
# 6       1
# 7       1
# 8       1
# 9       1
# 10      2
# 11      2
# 12      2
# 13      2
# 14      2
# 15      2
# 16      1
# 17      1
# 18      1
# 19      3
# 20      3
# 21      3
# 22      3
# 23      3
# 24      3
# 25      3
# 26      3
# 27      4
# 28      4
# 29      4
#        ..
# 102    11
# 103    11
# 104    11
# 105    11
# 106    11
# 107    11
# 108    11
# 109    11
# 110    11
# 111    11
# 112    11
# 113    11
# 114    11
# 115    11
# 116    11
# 117    11
# 118    11
# 119    11
# 120    11
# 121    11
# 122    12
# 123    12
# 124    12
# 125    12
# 126    13
# 127    13
# 128    14
# 129    14
# 130    14
# 131    14
# Name: category_id, Length: 132, dtype: int32

# %%
#
# Naive Bayes Classifier
#

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

#X_train, X_test, y_train, y_test = train_test_split(df['Value'], df['Category'], random_state = 0)
X_train, y_train = df['Value'], df['Category']

count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
#
# try making some predictions
#
value = 'current amp'
print(value, ' ', clf.predict(count_vect.transform([value])))

value = 'current 22 amp'
print(value, ' ', clf.predict(count_vect.transform([value])))

value = 'current 22 mamps'
print(value, ' ', clf.predict(count_vect.transform([value])))

value = 'current 22 milli amps'
print(value, ' ', clf.predict(count_vect.transform([value])))

value = 'voltage volts'
print(value, ' ',clf.predict(count_vect.transform([value])))

value = 'capacitance farads'
print(value, ' ',clf.predict(count_vect.transform([value])))

value = 'capacitance 5 μf'
print(value, ' ',clf.predict(count_vect.transform([value])))
# Out:
# current amp   ['amps']
# current 22 amp   ['amps']
# current 22 mamps   ['milli amps']
# current 22 milli amps   ['milli amps']
# voltage volts   ['volts']
# capacitance farads   ['micro farads']
# capacitance 5 μf   ['micro farads']
